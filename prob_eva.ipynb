# %%
import pandas as pd
pd.options.display.max_rows = 100

# %%
df = pd.read_csv('saved_csv/compare_test_df.csv', index_col=0)
df
# Out:
#      Actual  Predicted  Probabilities
# 0         0          1       0.999631
# 1         1          1       0.999710
# 2         1          1       0.996480
# 3         0          0       0.000727
# 4         0          0       0.006031
# ..      ...        ...            ...
# 619       1          1       0.999611
# 620       1          1       0.999876
# 621       1          1       0.999700
# 622       1          1       0.999995
# 623       1          1       0.980445
#
# [624 rows x 3 columns]

# %%
df.loc[df['Predicted'] != df['Actual'], "Right?"] = "wrong"
df.loc[df['Predicted'] == df['Actual'], "Right?"] = "correct"

# %%
df.head()
# Out:
#    Actual  Predicted  Probabilities   Right?
# 0       0          1       0.999631    wrong
# 1       1          1       0.999710  correct
# 2       1          1       0.996480  correct
# 3       0          0       0.000727  correct
# 4       0          0       0.006031  correct

# %%
df['Right?'].value_counts()
# Out:
# correct    538
# wrong       86
# Name: Right?, dtype: int64

# %%
df_wrong = df.loc[df['Right?'] == "wrong"]
df_wrong
# Out:
#      Actual  Predicted  Probabilities Right?
# 0         0          1       0.999631  wrong
# 11        0          1       0.572786  wrong
# 31        0          1       0.909978  wrong
# 34        0          1       0.998008  wrong
# 35        0          1       0.962811  wrong
# 37        1          0       0.025732  wrong
# 57        0          1       0.989099  wrong
# 59        0          1       0.590279  wrong
# 63        0          1       0.995546  wrong
# 80        0          1       0.941479  wrong
# 84        0          1       0.915132  wrong
# 87        0          1       0.732849  wrong
# 90        0          1       0.871047  wrong
# 93        0          1       0.985063  wrong
# 102       0          1       0.920318  wrong
# 106       0          1       0.959172  wrong
# 124       0          1       0.995670  wrong
# 133       0          1       0.908514  wrong
# 141       1          0       0.247935  wrong
# 147       0          1       0.771968  wrong
# 151       0          1       0.520306  wrong
# 160       0          1       0.889769  wrong
# 169       0          1       0.886752  wrong
# 173       0          1       0.999903  wrong
# 179       0          1       0.616210  wrong
# 188       0          1       0.973402  wrong
# 191       0          1       0.821714  wrong
# 199       0          1       0.985020  wrong
# 203       0          1       0.999508  wrong
# 215       0          1       0.999714  wrong
# 217       0          1       0.778527  wrong
# 220       0          1       0.685332  wrong
# 227       0          1       0.999372  wrong
# 231       0          1       0.810631  wrong
# 238       0          1       0.883923  wrong
# 243       0          1       0.907071  wrong
# 246       0          1       0.968660  wrong
# 259       0          1       0.680750  wrong
# 272       0          1       0.577828  wrong
# 285       0          1       0.996307  wrong
# 294       0          1       0.931659  wrong
# 298       0          1       0.999904  wrong
# 299       0          1       0.968105  wrong
# 302       0          1       0.990093  wrong
# 311       0          1       0.517833  wrong
# 315       0          1       0.868204  wrong
# 316       0          1       0.998297  wrong
# 322       0          1       0.931096  wrong
# 323       0          1       0.710701  wrong
# 326       0          1       0.999969  wrong
# 357       0          1       0.882606  wrong
# 378       1          0       0.211725  wrong
# 382       0          1       0.935999  wrong
# 385       0          1       0.917093  wrong
# 390       0          1       0.981169  wrong
# 396       1          0       0.298756  wrong
# 398       0          1       0.745180  wrong
# 400       1          0       0.007165  wrong
# 411       0          1       0.942606  wrong
# 414       0          1       0.786960  wrong
# 458       0          1       0.975816  wrong
# 473       0          1       0.812319  wrong
# 489       0          1       0.717640  wrong
# 492       0          1       0.593877  wrong
# 494       0          1       0.956081  wrong
# 518       1          0       0.344045  wrong
# 522       1          0       0.398030  wrong
# 526       0          1       0.993132  wrong
# 531       0          1       0.999593  wrong
# 535       0          1       0.989987  wrong
# 537       0          1       0.999400  wrong
# 539       0          1       0.965693  wrong
# 540       0          1       0.751429  wrong
# 541       0          1       0.617879  wrong
# 553       0          1       0.570070  wrong
# 554       0          1       0.997837  wrong
# 564       0          1       0.512082  wrong
# 570       0          1       0.999682  wrong
# 573       0          1       0.824536  wrong
# 575       0          1       0.778527  wrong
# 577       0          1       0.534068  wrong
# 578       0          1       0.749750  wrong
# 580       0          1       0.999924  wrong
# 589       0          1       0.999047  wrong
# 605       0          1       0.745788  wrong
# 609       0          1       0.994226  wrong

# %%
df_wrong_1 = df_wrong.loc[df_wrong['Actual'] == 1]
df_wrong_1
# Out:
#      Actual  Predicted  Probabilities Right?
# 37        1          0       0.025732  wrong
# 141       1          0       0.247935  wrong
# 378       1          0       0.211725  wrong
# 396       1          0       0.298756  wrong
# 400       1          0       0.007165  wrong
# 518       1          0       0.344045  wrong
# 522       1          0       0.398030  wrong

# %%
df_wrong_1.describe()
# Out:
#        Actual  Predicted  Probabilities
# count     7.0        7.0       7.000000
# mean      1.0        0.0       0.219055
# std       0.0        0.0       0.151198
# min       1.0        0.0       0.007165
# 25%       1.0        0.0       0.118728
# 50%       1.0        0.0       0.247935
# 75%       1.0        0.0       0.321400
# max       1.0        0.0       0.398030

# %%
df_wrong_0 = df_wrong.loc[df_wrong['Actual'] == 0]
df_wrong_0
# Out:
#      Actual  Predicted  Probabilities Right?
# 0         0          1       0.999631  wrong
# 11        0          1       0.572786  wrong
# 31        0          1       0.909978  wrong
# 34        0          1       0.998008  wrong
# 35        0          1       0.962811  wrong
# 57        0          1       0.989099  wrong
# 59        0          1       0.590279  wrong
# 63        0          1       0.995546  wrong
# 80        0          1       0.941479  wrong
# 84        0          1       0.915132  wrong
# 87        0          1       0.732849  wrong
# 90        0          1       0.871047  wrong
# 93        0          1       0.985063  wrong
# 102       0          1       0.920318  wrong
# 106       0          1       0.959172  wrong
# 124       0          1       0.995670  wrong
# 133       0          1       0.908514  wrong
# 147       0          1       0.771968  wrong
# 151       0          1       0.520306  wrong
# 160       0          1       0.889769  wrong
# 169       0          1       0.886752  wrong
# 173       0          1       0.999903  wrong
# 179       0          1       0.616210  wrong
# 188       0          1       0.973402  wrong
# 191       0          1       0.821714  wrong
# 199       0          1       0.985020  wrong
# 203       0          1       0.999508  wrong
# 215       0          1       0.999714  wrong
# 217       0          1       0.778527  wrong
# 220       0          1       0.685332  wrong
# 227       0          1       0.999372  wrong
# 231       0          1       0.810631  wrong
# 238       0          1       0.883923  wrong
# 243       0          1       0.907071  wrong
# 246       0          1       0.968660  wrong
# 259       0          1       0.680750  wrong
# 272       0          1       0.577828  wrong
# 285       0          1       0.996307  wrong
# 294       0          1       0.931659  wrong
# 298       0          1       0.999904  wrong
# 299       0          1       0.968105  wrong
# 302       0          1       0.990093  wrong
# 311       0          1       0.517833  wrong
# 315       0          1       0.868204  wrong
# 316       0          1       0.998297  wrong
# 322       0          1       0.931096  wrong
# 323       0          1       0.710701  wrong
# 326       0          1       0.999969  wrong
# 357       0          1       0.882606  wrong
# 382       0          1       0.935999  wrong
# 385       0          1       0.917093  wrong
# 390       0          1       0.981169  wrong
# 398       0          1       0.745180  wrong
# 411       0          1       0.942606  wrong
# 414       0          1       0.786960  wrong
# 458       0          1       0.975816  wrong
# 473       0          1       0.812319  wrong
# 489       0          1       0.717640  wrong
# 492       0          1       0.593877  wrong
# 494       0          1       0.956081  wrong
# 526       0          1       0.993132  wrong
# 531       0          1       0.999593  wrong
# 535       0          1       0.989987  wrong
# 537       0          1       0.999400  wrong
# 539       0          1       0.965693  wrong
# 540       0          1       0.751429  wrong
# 541       0          1       0.617879  wrong
# 553       0          1       0.570070  wrong
# 554       0          1       0.997837  wrong
# 564       0          1       0.512082  wrong
# 570       0          1       0.999682  wrong
# 573       0          1       0.824536  wrong
# 575       0          1       0.778527  wrong
# 577       0          1       0.534068  wrong
# 578       0          1       0.749750  wrong
# 580       0          1       0.999924  wrong
# 589       0          1       0.999047  wrong
# 605       0          1       0.745788  wrong
# 609       0          1       0.994226  wrong

# %%
df_wrong_0.describe()
# Out:
#        Actual  Predicted  Probabilities
# count    79.0       79.0      79.000000
# mean      0.0        1.0       0.863113
# std       0.0        0.0       0.151517
# min       0.0        1.0       0.512082
# 25%       0.0        1.0       0.761699
# 50%       0.0        1.0       0.920318
# 75%       0.0        1.0       0.991613
# max       0.0        1.0       0.999969
